# %%
import pandas as pd
import os
from IPython.display import display

# %%
path = '/home/chernov.kirill9/projects/gases/gases-sensors/catboost/results/exp3_melted_on_exp_4'

# %%
for i in range(1, 13):
    print(f'R{i}')
    df = pd.read_csv(os.path.join(path, f'R{i}_test_metrics.csv'))
    df.set_index('Unnamed: 0', inplace=True)
    df.index.name = None
    display(df)
# Out:
# R1
#                         NO       CH4       H2S       SO2      HCOH        CO  \
# linear           -0.206771  0.262745  0.377345 -1.165001  0.092340  0.555627
# linear_short      0.650044  0.326533  0.229542 -0.392087  0.599924  0.156867
# steps_up         -0.629560  0.196779  0.194142 -1.169650  0.716149  0.806326
# steps_up_pulse   -1.049904  0.484246  0.790351 -0.100714  0.023453  0.899712
# steps_down       -0.705482 -0.729115  0.110214 -0.319257  0.390202  0.394295
# steps_down_pulse  0.477009  0.291898  0.228838 -0.660078  0.027303  0.477168
#
#                            H2       NO2       NH3
# linear           -1056.206804 -2.713747 -0.507570
# linear_short         0.229542 -1.657627  0.317036
# steps_up            -0.298761 -0.182315  0.600957
# steps_up_pulse       0.790351 -1.049904 -0.745622
# steps_down           0.110214  0.008040  0.300743
# steps_down_pulse     0.223965 -0.218135  0.317609
# R2
# ...
